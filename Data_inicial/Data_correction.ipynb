# %%
import pandas as pd
import numpy as np

# %%
df_coord = pd.read_excel('df_hechos_excel.xlsx')

# %%
df_coord.head()
# Out:
#    Unnamed: 0        ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 0           0  20160001           1 2016-01-01  2016   1   1  04:00:00   4
# 1           1  20160002           1 2016-01-02  2016   1   2  01:15:00   1
# 2           2  20160003           1 2016-01-03  2016   1   3  07:00:00   7
# 3           3  20160004           1 2016-01-10  2016   1  10  00:00:00   0
# 4           4  20160005           1 2016-01-21  2016   1  21  05:20:00   5
#
#                              LUGAR_DEL_HECHO  ...   Longitud    Latitud  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ  ... -58.475340 -34.687570
# 1          AV GRAL PAZ  Y AV DE LOS CORRALES  ... -58.508775 -34.669777
# 2                         AV ENTRE RIOS 2034  ... -58.390403 -34.631894
# 3      AV LARRAZABAL Y GRAL VILLEGAS CONRADO  ... -58.465039 -34.680930
# 4  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA   ... -58.387183 -34.622466
#
#       PARTICIPANTES VICTIMA    ACUSADO        ROL       SEXO EDAD  \
# ...

# %%
df_coord.drop(columns={'N_VICTIMAS','FECHA','AAAA','MM','DD','HORA','HH','LUGAR_DEL_HECHO','TIPO_DE_CALLE','PARTICIPANTES','VICTIMA','ACUSADO','ROL','SEXO','EDAD','FECHA_FALLECIMIENTO'},inplace=True)

# %%
df_coord['Longitud'].replace(0,-58.475340, inplace=True)

# %%
df_coord['Latitud'].replace(0,-34.687570, inplace=True)

# %%
df_coord.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             716 non-null    int64
#  1   ID                     716 non-null    int64
#  2   Dirección Normalizada  716 non-null    object
#  3   COMUNA                 716 non-null    int64
#  4   XY (CABA)              716 non-null    object
#  5   Longitud               716 non-null    float64
#  6   Latitud                716 non-null    float64
#  7   SEMESTRE               716 non-null    int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 44.9+ KB

# %%
df_coord['Latitud'].replace('.',',',inplace=True)
df_coord['Longitud'].replace('.',',',inplace=True)

# %%
df_coord.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             716 non-null    int64
#  1   ID                     716 non-null    int64
#  2   Dirección Normalizada  716 non-null    object
#  3   COMUNA                 716 non-null    int64
#  4   XY (CABA)              716 non-null    object
#  5   Longitud               716 non-null    float64
#  6   Latitud                716 non-null    float64
#  7   SEMESTRE               716 non-null    int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 44.9+ KB

# %%
df_coord.head()
# Out:
#    Unnamed: 0        ID                              Dirección Normalizada  \
# 0           0  20160001  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...
# 1           1  20160002               PAZ, GRAL. AV. y DE LOS CORRALES AV.
# 2           2  20160003                                ENTRE RIOS AV. 2034
# 3           3  20160004          LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.
# 4           4  20160005            SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.
#
#    COMUNA                                XY (CABA)   Longitud    Latitud  \
# 0       8    Point (98896.78238426 93532.43437792) -58.475340 -34.687570
# 1       9    Point (95832.05571093 95505.41641999) -58.508775 -34.669777
# 2       1   Point (106684.29090040 99706.57687843) -58.390403 -34.631894
# 3       8    Point (99840.65224780 94269.16534422) -58.465039 -34.680930
# 4       1  Point (106980.32827929 100752.16915795) -58.387183 -34.622466
#
#    SEMESTRE
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
df_coord.to_excel('Coordenadas.xlsx')

# %%
df_coord.to_csv('Coordenadas.csv',index=True)
